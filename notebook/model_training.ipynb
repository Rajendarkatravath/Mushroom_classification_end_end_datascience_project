# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\Good Morning\AppData\Local\Temp\ipykernel_462404\2162656668.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df=pd.read_csv("E:/Mushrooms_classfication_project/notebook/mushrooms.csv")
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
# finding the null values in the dataset
df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
# finding the unqiue values in the dataset
df.nunique()
# Out:
# class                        2
# cap-shape                    6
# cap-surface                  4
# cap-color                   10
# bruises                      2
# odor                         9
# gill-attachment              2
# gill-spacing                 2
# gill-size                    2
# gill-color                  12
# stalk-shape                  2
# stalk-root                   5
# stalk-surface-above-ring     4
# stalk-surface-below-ring     4
# stalk-color-above-ring       9
# stalk-color-below-ring       9
# veil-type                    1
# veil-color                   4
# ring-number                  3
# ring-type                    5
# spore-print-color            9
# population                   6
# habitat                      7
# dtype: int64

# %%
# information about the coloumns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
# dependent columns
X=df.iloc[:,1:]

# %%
X
# Out:
#      cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0            x           s         n       t    p               f
# 1            x           s         y       t    a               f
# 2            b           s         w       t    l               f
# 3            x           y         w       t    p               f
# 4            x           s         g       f    n               f
# ...        ...         ...       ...     ...  ...             ...
# 8119         k           s         n       f    n               a
# 8120         x           s         n       f    n               a
# 8121         f           s         n       f    n               a
# 8122         k           y         n       f    y               f
# 8123         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color stalk-shape  ...  \
# 0               c         n          k           e  ...
# 1               c         b          k           e  ...
# ...

# %%
# target varaiable
y=df.iloc[:,1]

# %%
y
# Out:
# 0       p
# 1       e
# 2       e
# 3       p
# 4       e
#        ..
# 8119    e
# 8120    e
# 8121    e
# 8122    p
# 8123    e
# Name: class, Length: 8124, dtype: object

# %%
#feature engineering
from sklearn.preprocessing import LabelEncoder

#Assuming y is the target variable
le = LabelEncoder()
y = le.fit_transform(y)

# %%
X=pd.get_dummies(X)
X
# Out:
#       cap-shape_b  cap-shape_c  cap-shape_f  cap-shape_k  cap-shape_s  \
# 0           False        False        False        False        False
# 1           False        False        False        False        False
# 2            True        False        False        False        False
# 3           False        False        False        False        False
# 4           False        False        False        False        False
# ...           ...          ...          ...          ...          ...
# 8119        False        False        False         True        False
# 8120        False        False        False        False        False
# 8121        False        False         True        False        False
# 8122        False        False        False         True        False
# 8123        False        False        False        False        False
#
#       cap-shape_x  cap-surface_f  cap-surface_g  cap-surface_s  cap-surface_y  \
# ...

# %%
# spliting the dataset for training and testing
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=40)

# %%
X_train
# Out:
#       cap-shape_b  cap-shape_c  cap-shape_f  cap-shape_k  cap-shape_s  \
# 7478        False        False        False         True        False
# 1473        False        False         True        False        False
# 2028        False        False        False        False        False
# 6254        False        False         True        False        False
# 7858        False        False        False        False        False
# ...           ...          ...          ...          ...          ...
# 3064        False        False        False        False        False
# 6309        False        False         True        False        False
# 6151        False        False         True        False        False
# 6363        False        False         True        False        False
# 3398        False        False        False        False        False
#
#       cap-shape_x  cap-surface_f  cap-surface_g  cap-surface_s  cap-surface_y  \
# ...

# %%
# all models in one code
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.model_selection import train_test_split
import warnings

# Define the evaluation function
def evaluate_model(true, predicted):
    cm = confusion_matrix(true, predicted)
    classification_reports = classification_report(true, predicted)
    acc_score = accuracy_score(true, predicted)  # Rename the variable here

    return cm, classification_reports, acc_score



# Define the models
models = {
    "Logistic Regression": LogisticRegression(C=0.001, penalty='l2', solver='liblinear'),
    "SVM Classifier": svm.SVC(kernel='linear', C=0.0001),
    "Decision Tree": DecisionTreeClassifier(criterion='entropy', max_depth=1, min_samples_leaf=5),
    "Random Forest Classifier": RandomForestClassifier(n_estimators=50, max_depth=1, min_samples_leaf=5),
    "Gradient Boosting Classifier": GradientBoostingClassifier(n_estimators=15, max_depth=1, min_samples_leaf=3, learning_rate=0.1),
    "AdaBoost Classifier": AdaBoostClassifier(n_estimators=2, learning_rate=1.0, algorithm='SAMME')

}

# Iterate over the models
for name, model in models.items():
    model.fit(X_train, y_train) # Train model

    # Make predictions
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    # Evaluate Train and Test dataset
    cm_train, cr_train, as_train = evaluate_model(y_train, y_train_pred)
    cm_test, cr_test, as_test = evaluate_model(y_test, y_test_pred)

    print(name)

    print('Model performance for Training set')
    print("- Confusion Matrix:\n", cm_train)
    print("- Classification Report:\n", cr_train)
    print("- Accuracy Score: {:.4f}".format(as_train))

    print('----------------------------------')

    print('Model performance for Test set')
    print("- Confusion Matrix:\n", cm_test)
    print("- Classification Report:\n", cr_test)
    print("- Accuracy Score: {:.4f}".format(as_test))
    print('\n')
# Out:
# Logistic Regression
# Model performance for Training set
# - Confusion Matrix:
#  [[2898   62]
#  [ 350 2376]]
# - Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93      2960
#            1       0.97      0.87      0.92      2726
#
#     accuracy                           0.93      5686
#    macro avg       0.93      0.93      0.93      5686
# weighted avg       0.93      0.93      0.93      5686
#
# - Accuracy Score: 0.9275
# ----------------------------------
# Model performance for Test set
# - Confusion Matrix:
#  [[1222   26]
#  [ 147 1043]]
# - Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93      1248
#            1       0.98      0.88      0.92      1190
#
#     accuracy                           0.93      2438
#    macro avg       0.93      0.93      0.93      2438
# ...
